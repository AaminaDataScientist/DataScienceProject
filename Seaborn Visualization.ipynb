# %% [markdown]
# # Seaborn Visualization

# %%
import pandas as pd
import matplotlib.pyplot as  plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips=sns.load_dataset('tips')
print(tips.head())
sns.violinplot(x="total_bill", data=tips)
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips["tip"], bins=20)

# %%
sns.distplot(tips["total_bill"], bins=20, kde=False)

# %%
sns.kdeplot(tips["total_bill"])

# %%
sns.displot(data=tips, kind="ecdf", x="total_bill", col="time", hue="smoker")

# %%
sns.jointplot(data=tips, x="total_bill", y="tip")

# %%
sns.rugplot(data=tips, x='tip')

# %%
sns.rugplot(data=tips, x='total_bill', y='tip')

# %%
sns.boxplot(x='day', y='total_bill', hue='smoker', data=tips, palette="coolwarm")

# %%
sns.pairplot(tips)

# %%
sns.boxplot?

# %%
sns.catplot(x='day', y="total_bill", kind="box", data=tips, palette="coolwarm")

# %%
sns.histplot(data=tips, x="total_bill", bins=20)

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", data=tips, kind="box")
plt.title("Customer Vists")
# Out:
# Text(0.5, 1, 'Customer Vists')

# %%
sns.set()

# %%
sns.set_context("paper")
iris=sns.load_dataset("iris")
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.swarmplot(x="species", y="petal_width", data=iris)

# %%
mpgds=sns.load_dataset('mpg')
mpgds
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.histplot(x="mpg", y="horsepower", data=mpgds)

# %%
sns.scatterplot(data=mpgds, x="mpg", y="weight")

# %%
sns.scatterplot(data=mpgds, x="mpg", y="horsepower")

# %%
sns.lineplot(data=mpgds, x="mpg", y="acceleration")

# %%
sns.rugplot(mpgds["weight"], x="mpg")

# %%
sns.relplot(data=mpgds, x="mpg", y="weight")

# %%
sns.pairplot(mpgds)

# %%
sns.regplot(data=mpgds, x="mpg", y="horsepower")

# %%
sns.lmplot(data=mpgds, x="acceleration", y="weight")

# %%
sns.boxplot(x="displacement", y="mpg", data=mpgds)

# %%
sns.boxplot(data=mpgds, x="mpg")

# %%
sns.boxplot(data=mpgds, x="acceleration")

# %%
sns.stripplot(data=mpgds, x="origin", y="mpg")

# %%
sns.swarmplot(data=mpgds, x="weight", y="acceleration")

# %%
sns.jointplot(data=mpgds, x="mpg", y="displacement", kind='hex', palette="coolwarm", color="blue")

# %%
sns.jointplot(data=mpgds, x="mpg", y="displacement", kind='kde')

# %%
sns.catplot(data=mpgds, x="weight", y="acceleration")

# %%
sns.catplot(data=mpgds, x="weight", y="acceleration", kind="box")

# %% [markdown]
# # Using Pivot and Heatmap

# %%
flight=sns.load_dataset("flights")
flight=flight.pivot("month", "year", "passengers")
flight
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
ax=sns.heatmap(flight)
